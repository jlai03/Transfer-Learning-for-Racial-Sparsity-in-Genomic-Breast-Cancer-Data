# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Open Processed Clinical Data
datapath = "../data/processed_labels/clinical.tsv"
df = pd.read_csv(datapath, sep='\t')
df
# Out:
#                                   case_id  age_at_index  gender  \
# 0    001cef41-ff86-4d3f-a140-a647ac4b10a1            60  female
# 1    001cef41-ff86-4d3f-a140-a647ac4b10a1            60  female
# 2    011b9b2d-ebe5-42bf-9662-d922faccc7a1            71  female
# 3    011b9b2d-ebe5-42bf-9662-d922faccc7a1            71  female
# 4    0130d616-885e-4a6c-9d03-2f17dd692a05            74  female
# ..                                    ...           ...     ...
# 633  fe7f74b8-20f4-4471-91dc-4cca8c68e5c0            46  female
# 634  fec0da58-1047-44d2-b6d1-c18cceed43dc            71  female
# 635  fec0da58-1047-44d2-b6d1-c18cceed43dc            71  female
# 636  ff0f875f-113a-4c0f-8c0a-4259cd496e6d            58  female
# 637  ff0f875f-113a-4c0f-8c0a-4259cd496e6d            58  female
#
#     ajcc_pathologic_stage                 primary_diagnosis prior_malignancy
# 0                Stage IA  Infiltrating duct carcinoma, NOS               no
# 1                Stage IA  Infiltrating duct carcinoma, NOS               no
# 2              Stage IIIA            Lobular carcinoma, NOS              yes
# 3              Stage IIIA            Lobular carcinoma, NOS              yes
# 4               Stage IIA  Infiltrating duct carcinoma, NOS               no
# ..                    ...                               ...              ...
# 633               Stage I  Infiltrating duct carcinoma, NOS               no
# 634             Stage IIA            Lobular carcinoma, NOS               no
# 635             Stage IIA            Lobular carcinoma, NOS               no
# 636             Stage IIB  Infiltrating duct carcinoma, NOS               no
# 637             Stage IIB  Infiltrating duct carcinoma, NOS               no
#
# [638 rows x 6 columns]

# %%
# Count unique values in the 'Category' column
value_counts = df['primary_diagnosis'].value_counts()
value_counts
# Out:
# primary_diagnosis
# Infiltrating duct carcinoma, NOS                            468
# Lobular carcinoma, NOS                                      122
# Infiltrating duct and lobular carcinoma                      12
# Infiltrating duct mixed with other types of carcinoma         8
# Infiltrating lobular mixed with other types of carcinoma      4
# Intraductal micropapillary carcinoma                          4
# Mucinous adenocarcinoma                                       4
# Metaplastic carcinoma, NOS                                    4
# Secretory carcinoma of breast                                 2
# Intraductal papillary adenocarcinoma with invasion            2
# Carcinoma, NOS                                                2
# Tubular adenocarcinoma                                        2
# Medullary carcinoma, NOS                                      2
# Basal cell carcinoma, NOS                                     2
# Name: count, dtype: int64

# %%
# Plotting the bar graph
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Count of Unique Values in Category Column')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()
