# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Open Processed Clinical Data
datapath = "data/processed_labels/clinical.tsv"
df = pd.read_csv(datapath, sep='\t')
df
# Out:
#                                    case_id  age_at_index  gender  \
# 0     001cef41-ff86-4d3f-a140-a647ac4b10a1            60  female
# 1     001cef41-ff86-4d3f-a140-a647ac4b10a1            60  female
# 2     0045349c-69d9-4306-a403-c9c1fa836644            70  female
# 3     0045349c-69d9-4306-a403-c9c1fa836644            70  female
# 4     00807dae-9f4a-4fd1-aac2-82eb11bf2afb            50  female
# ...                                    ...           ...     ...
# 2121  fe7f74b8-20f4-4471-91dc-4cca8c68e5c0            46  female
# 2122  fec0da58-1047-44d2-b6d1-c18cceed43dc            71  female
# 2123  fec0da58-1047-44d2-b6d1-c18cceed43dc            71  female
# 2124  ff0f875f-113a-4c0f-8c0a-4259cd496e6d            58  female
# 2125  ff0f875f-113a-4c0f-8c0a-4259cd496e6d            58  female
#
#      ajcc_pathologic_stage                 primary_diagnosis prior_malignancy
# 0                 Stage IA  Infiltrating duct carcinoma, NOS               no
# 1                 Stage IA  Infiltrating duct carcinoma, NOS               no
# 2                  Stage I          Adenoid cystic carcinoma               no
# 3                  Stage I          Adenoid cystic carcinoma               no
# 4                Stage IIB           Apocrine adenocarcinoma               no
# ...                    ...                               ...              ...
# 2121               Stage I  Infiltrating duct carcinoma, NOS               no
# 2122             Stage IIA            Lobular carcinoma, NOS               no
# 2123             Stage IIA            Lobular carcinoma, NOS               no
# 2124             Stage IIB  Infiltrating duct carcinoma, NOS               no
# 2125             Stage IIB  Infiltrating duct carcinoma, NOS               no
#
# [2126 rows x 6 columns]

# %%
# Count unique values in the 'Category' column
value_counts = df['primary_diagnosis'].value_counts()
value_counts
# Out:
# Infiltrating duct carcinoma, NOS                            1500
# Lobular carcinoma, NOS                                       394
# Infiltrating duct and lobular carcinoma                       54
# Infiltrating duct mixed with other types of carcinoma         38
# Mucinous adenocarcinoma                                       32
# Metaplastic carcinoma, NOS                                    28
# Infiltrating lobular mixed with other types of carcinoma      14
# Intraductal papillary adenocarcinoma with invasion            10
# Medullary carcinoma, NOS                                      10
# Intraductal micropapillary carcinoma                           8
# Pleomorphic carcinoma                                          6
# Paget disease and infiltrating duct carcinoma of breast        6
# Phyllodes tumor, malignant                                     4
# Papillary carcinoma, NOS                                       4
# Carcinoma, NOS                                                 2
# Adenoid cystic carcinoma                                       2
# Tubular adenocarcinoma                                         2
# Cribriform carcinoma, NOS                                      2
# Secretory carcinoma of breast                                  2
# Apocrine adenocarcinoma                                        2
# Large cell neuroendocrine carcinoma                            2
# Malignant lymphoma, large B-cell, diffuse, NOS                 2
# Basal cell carcinoma, NOS                                      2
# Name: primary_diagnosis, dtype: int64

# %%
# Plotting the bar graph
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Count of Unique Values in Category Column')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()
