# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Open Processed Clinical Data
datapath = "../data/processed_labels/clinical.tsv"
df = pd.read_csv(datapath, sep='\t')
df
# Out:
#                                    case_id  age_at_index  gender  \
# 0     0045349c-69d9-4306-a403-c9c1fa836644            70  female
# 1     0045349c-69d9-4306-a403-c9c1fa836644            70  female
# 2     00807dae-9f4a-4fd1-aac2-82eb11bf2afb            50  female
# 3     00807dae-9f4a-4fd1-aac2-82eb11bf2afb            50  female
# 4     00a2d166-78c9-4687-a195-3d6315c27574            56  female
# ...                                    ...           ...     ...
# 1799  fe7f74b8-20f4-4471-91dc-4cca8c68e5c0            46  female
# 1800  fec0da58-1047-44d2-b6d1-c18cceed43dc            71  female
# 1801  fec0da58-1047-44d2-b6d1-c18cceed43dc            71  female
# 1802  ff0f875f-113a-4c0f-8c0a-4259cd496e6d            58  female
# 1803  ff0f875f-113a-4c0f-8c0a-4259cd496e6d            58  female
#
#                            race ajcc_pathologic_stage  \
# 0                         white               Stage I
# 1                         white               Stage I
# ...

# %%
# Count unique values in the 'Primary Diagnosis' column
value_counts = df['primary_diagnosis'].value_counts()
value_counts
# Out:
# primary_diagnosis
# Infiltrating duct carcinoma, NOS                            1276
# Lobular carcinoma, NOS                                       338
# Infiltrating duct and lobular carcinoma                       46
# Infiltrating duct mixed with other types of carcinoma         30
# Metaplastic carcinoma, NOS                                    24
# Mucinous adenocarcinoma                                       20
# Intraductal micropapillary carcinoma                           8
# Infiltrating lobular mixed with other types of carcinoma       8
# Intraductal papillary adenocarcinoma with invasion             8
# Medullary carcinoma, NOS                                       8
# Pleomorphic carcinoma                                          6
# Paget disease and infiltrating duct carcinoma of breast        6
# Phyllodes tumor, malignant                                     4
# Papillary carcinoma, NOS                                       4
# ...

# %%
# Plotting the bar graph
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Prognoses')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()

# %%
# Count unique values in the 'Race' column
race_counts = df['race'].value_counts()
race_counts
# Out:
# race
# white                               1232
# black or african american            302
# not reported                         160
# asian                                108
# american indian or alaska native       2
# Name: count, dtype: int64

# %%
# Plotting the bar graph
plt.figure(figsize=(4, 5))
race_counts.plot(kind='bar', color='pink')
plt.title('Distribution of Race')
plt.xlabel('Race')
plt.ylabel('Count')
plt.show()

# %%
# Clean up DF 
filtered_df = df[df.race != "not reported"]
race_counts = filtered_df['race'].value_counts()

# Plot Pie Chart of Race 
plt.figure(figsize=(10, 10))
plt.pie(race_counts, labels=race_counts.index, autopct='%1.1f%%', startangle=140, labeldistance=None, colors=["dodgerblue", "palegreen", "gainsboro", "red"])
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Categories')
plt.legend()
plt.show()
